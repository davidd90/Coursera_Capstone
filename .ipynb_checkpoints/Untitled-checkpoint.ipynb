# %%
import bs4 as bs
import urllib.request 
import time 
from datetime import datetime 
import pandas as pd
import json
import os

# %%
max_time = 3600
start_time = time.time()
count = 1
l=[]
df = pd.DataFrame()

for page in range(1,10):
    print("Loop " + str(count) + " startet.")
    try:
        soup = bs.BeautifulSoup(urllib.request.urlopen('https://www.immobilienscout24.de/Suche/de/sachsen/leipzig/wohnung-mieten?pagenumber='+str(page)).read(),'lxml')
        for paragraph in soup.find_all("a"):
            if r"/expose/" in str(paragraph.get("href")): 
                l.append(paragraph.get("href").split("#")[0]) 
                l = list(set(l))
        for item in l:
            try:
                soup = bs.BeautifulSoup(urllib.request.urlopen('https://www.immobilienscout24.de'+item).read(),'lxml')
                scripts = str(soup.find_all("script"))
                data = pd.DataFrame(json.loads(scripts.split("keyValues = ")[1].split("}")[0]+str("}")),index=[str(datetime.now())])
                data["URL"] = str(item)
                beschreibung = [] 

                for i in soup.find_all("pre"): 
                    beschreibung.append(i.text)
                    
                json_text = '{%s}' % (scripts.partition('{')[2].rpartition('}')[0]
                value = json.loads(json_text)
                print(value)
                #print(str(soup.find_all("script")).split("IS24.expose.mapModel = ")[1].split("{")[4].split("}")[0].split("\n"))
                position = json.loads(str(soup.find_all("script")).split("IS24.expose.mapModel = ")[1].split("{")[4].split("}")[0]+str("}"))
                try:
                    data["lat"] = position["lat"]
                    data["long"] = position["lng"]
                except KeyError:
                    continue
                    
                data["beschreibung"] = str(beschreibung)
                df = df.append(data)
            except Exception as e:
                print(str(datetime.now())+": " + str(e)) 
                l = list(filter(lambda x: x != item, l))
                print("ID " + str(item) + " entfernt.")
    except Exception as e: 
        print(str(datetime.now())+": " + str(e)) 
    print("Loop " + str(count) + " endet.")  
    count+=1 
df.to_csv("Rohdaten/"+str(datetime.now())[:19].replace(":","").replace(".","")+".csv",sep=";",decimal=",",encoding = "utf-8",index_label="timestamp")
print("FERTIG!")
# Out:
# Loop 1 startet.
# ['', '        lat: 51.36954171527326,', '        lng: 12.348725010566346', '        ']
# 2019-12-22 09:29:14.310532: Expecting value: line 2 column 9 (char 9)
# ID /expose/114875055 entfernt.
# ['', '        lat: 51.37991549868058,', '        lng: 12.431727846856228', '        ']
# 2019-12-22 09:29:15.306123: Expecting value: line 2 column 9 (char 9)
# ID /expose/114121224 entfernt.
# ['', '        lat: 51.34483691370461,', '        lng: 12.408785337305138', '        ']
# 2019-12-22 09:29:16.283355: Expecting value: line 2 column 9 (char 9)
# ID /expose/97164417 entfernt.
# ['', '        lat: 51.33475445762971,', '        lng: 12.475476585419747', '        ']
# 2019-12-22 09:29:17.099645: Expecting value: line 2 column 9 (char 9)
# ID /expose/110886227 entfernt.
# ['', '        lat: 51.32585551747139,', '        lng: 12.336525987418709', '        ']
# 2019-12-22 09:29:18.000747: Expecting value: line 2 column 9 (char 9)
# ID /expose/111760897 entfernt.
# ['', '        lat: 51.350394340609135,', '        lng: 12.373567704147431', '        ']
# 2019-12-22 09:29:18.935510: Expecting value: line 2 column 9 (char 9)
# ID /expose/103259028 entfernt.
# ['', '        lat: 51.34128875531738,', '        lng: 12.403645220941574', '        ']
# 2019-12-22 09:29:19.725969: Expecting value: line 2 column 9 (char 9)
# ID /expose/109687708 entfernt.
# ['', '        lat: 51.31956544333312,', '        lng: 12.369185387285748', '        ']
# 2019-12-22 09:29:20.607198: Expecting value: line 2 column 9 (char 9)
# ID /expose/110888989 entfernt.
# ['', '        lat: 51.31955134670136,', '        lng: 12.375829213998689', '        ']
# 2019-12-22 09:29:21.516625: Expecting value: line 2 column 9 (char 9)
# ID /expose/110885983 entfernt.
# ['', '        lat: 51.3333456362768,', '        lng: 12.44120590789379', '        ']
# 2019-12-22 09:29:22.460331: Expecting value: line 2 column 9 (char 9)
# ID /expose/97007342 entfernt.
# ['', '        lat: 51.33231932467792,', '        lng: 12.315585091271858', '        ']
# 2019-12-22 09:29:23.470113: Expecting value: line 2 column 9 (char 9)
# ID /expose/114943552 entfernt.
# ['', '        lat: 51.32585551747139,', '        lng: 12.336525987418709', '        ']
# 2019-12-22 09:29:24.451033: Expecting value: line 2 column 9 (char 9)
# ID /expose/111759298 entfernt.
# ['', '        lat: 51.30734166344628,', '        lng: 12.319617795069773', '        ']
# 2019-12-22 09:29:25.215452: Expecting value: line 2 column 9 (char 9)
# ID /expose/113806542 entfernt.
# ['', '        lat: 51.372958246634965,', '        lng: 12.356016305803454', '        ']
# 2019-12-22 09:29:26.191332: Expecting value: line 2 column 9 (char 9)
# ID /expose/114460432 entfernt.
# ['', '        lat: 51.331232776963304,', '        lng: 12.399730447139785', '        ']
# 2019-12-22 09:29:27.191722: Expecting value: line 2 column 9 (char 9)
# ID /expose/113327280 entfernt.
# ['', '        lat: 51.32585551747139,', '        lng: 12.336525987418709', '        ']
# 2019-12-22 09:29:28.081253: Expecting value: line 2 column 9 (char 9)
# ID /expose/111751353 entfernt.
# ['', '        lat: 51.34180949087911,', '        lng: 12.383699600175307', '        ']
# 2019-12-22 09:29:28.913268: Expecting value: line 2 column 9 (char 9)
# ID /expose/113940930 entfernt.
# ['', '            position: google.maps.ControlPosition.TOP_RIGHT', '          ']
# 2019-12-22 09:29:29.831874: Expecting value: line 2 column 13 (char 13)
# ID /expose/114892679 entfernt.
# ['', '        lat: 51.385249138999725,', '        lng: 12.350874744976187', '        ']
# 2019-12-22 09:29:30.767523: Expecting value: line 2 column 9 (char 9)
# ID /expose/114360714 entfernt.
# ['', '        lat: 51.35300300157081,', '        lng: 12.370959269964507', '        ']
# 2019-12-22 09:29:31.642854: Expecting value: line 2 column 9 (char 9)
# ID /expose/84831167 entfernt.
# ['', '        lat: 51.342745455653564,', '        lng: 12.386196715507445', '        ']
# 2019-12-22 09:29:32.481492: Expecting value: line 2 column 9 (char 9)
# ID /expose/106346755 entfernt.
# ['', '        lat: 51.3030357441899,', '        lng: 12.325026006989843', '        ']
# 2019-12-22 09:29:33.444595: Expecting value: line 2 column 9 (char 9)
# ID /expose/114621140 entfernt.
# Loop 1 endet.
# Loop 2 startet.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-8e30539f348d> in <module>
#       8     print("Loop " + str(count) + " startet.")
#       9     try:
# ---> 10         soup = bs.BeautifulSoup(urllib.request.urlopen('https://www.immobilienscout24.de/Suche/de/sachsen/leipzig/wohnung-mieten?pagenumber='+str(page)).read(),'lxml')
#      11         for paragraph in soup.find_all("a"):
#      12             if r"/expose/" in str(paragraph.get("href")):
#
# c:\users\ddamm\appdata\local\programs\python\python37\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# c:\users\ddamm\appdata\local\programs\python\python37\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# c:\users\ddamm\appdata\local\programs\python\python37\lib\urllib\request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# c:\users\ddamm\appdata\local\programs\python\python37\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# c:\users\ddamm\appdata\local\programs\python\python37\lib\urllib\request.py in https_open(self, req)
#    1358         def https_open(self, req):
#    1359             return self.do_open(http.client.HTTPSConnection, req,
# -> 1360                 context=self._context, check_hostname=self._check_hostname)
#    1361
#    1362         https_request = AbstractHTTPHandler.do_request_
#
# c:\users\ddamm\appdata\local\programs\python\python37\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1315             try:
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#    1319                 raise URLError(err)
#
# c:\users\ddamm\appdata\local\programs\python\python37\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1250                 encode_chunked=False):
#    1251         """Send a complete request to the server."""
# -> 1252         self._send_request(method, url, body, headers, encode_chunked)
#    1253
#    1254     def _send_request(self, method, url, body, headers, encode_chunked):
#
# c:\users\ddamm\appdata\local\programs\python\python37\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1296             # default charset of iso-8859-1.
#    1297             body = _encode(body, 'body')
# -> 1298         self.endheaders(body, encode_chunked=encode_chunked)
#    1299
#    1300     def getresponse(self):
#
# c:\users\ddamm\appdata\local\programs\python\python37\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1245         else:
#    1246             raise CannotSendHeader()
# -> 1247         self._send_output(message_body, encode_chunked=encode_chunked)
#    1248
#    1249     def request(self, method, url, body=None, headers={}, *,
#
# c:\users\ddamm\appdata\local\programs\python\python37\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1024         msg = b"\r\n".join(self._buffer)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#    1028         if message_body is not None:
#
# c:\users\ddamm\appdata\local\programs\python\python37\lib\http\client.py in send(self, data)
#     964         if self.sock is None:
#     965             if self.auto_open:
# --> 966                 self.connect()
#     967             else:
#     968                 raise NotConnected()
#
# c:\users\ddamm\appdata\local\programs\python\python37\lib\http\client.py in connect(self)
#    1420
#    1421             self.sock = self._context.wrap_socket(self.sock,
# -> 1422                                                   server_hostname=server_hostname)
#    1423
#    1424     __all__.append("HTTPSConnection")
#
# c:\users\ddamm\appdata\local\programs\python\python37\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     421             server_hostname=server_hostname,
#     422             context=self,
# --> 423             session=session
#     424         )
#     425
#
# c:\users\ddamm\appdata\local\programs\python\python37\lib\ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#     868                         # non-blocking
#     869                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 870                     self.do_handshake()
#     871             except (OSError, ValueError):
#     872                 self.close()
#
# c:\users\ddamm\appdata\local\programs\python\python37\lib\ssl.py in do_handshake(self, block)
#    1137             if timeout == 0.0 and block:
#    1138                 self.settimeout(None)
# -> 1139             self._sslobj.do_handshake()
#    1140         finally:
#    1141             self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
df.to_csv("Rohdaten/"+str(datetime.now())[:19].replace(":","").replace(".","")+".csv",sep=";",decimal=",",encoding = "utf-8",index_label="timestamp")
print("FERTIG!")
